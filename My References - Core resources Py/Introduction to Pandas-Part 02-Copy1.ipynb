# %% [markdown]
# #### Loading the dependencies

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading the dataset

# %%
data = pd.read_csv('./titanic.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv('./titanic.csv')
#       2 data.head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ### droping the columns

# %%
data.columns

# %%
data.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace= True)

# %%
data.head(10)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
# 5         0       3    male   NaN      0      0   8.4583        Q
# 6         0       1    male  54.0      0      0  51.8625        S
# 7         0       3    male   2.0      3      1  21.0750        S
# 8         1       3  female  27.0      0      2  11.1333        S
# 9         1       2  female  14.0      1      0  30.0708        C

# %% [markdown]
# #### groupby

# %% [markdown]
# #### Gender wise average age

# %%
data.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.groupby(['Sex'])['Age'].mean().reset_index()
# Out:
#       Sex        Age
# 0  female  27.915709
# 1    male  30.726645

# %%
data.groupby(['Pclass'])['Age'].mean().reset_index()
# Out:
#    Pclass        Age
# 0       1  38.233441
# 1       2  29.877630
# 2       3  25.140620

# %%
data.groupby(['Embarked'])['Age'].mean().reset_index()
# Out:
#   Embarked        Age
# 0        C  30.814769
# 1        Q  28.089286
# 2        S  29.445397

# %%
data.groupby(['Pclass'])['Fare'].sum().reset_index()
# Out:
#    Pclass        Fare
# 0       1  18177.4125
# 1       2   3801.8417
# 2       3   6714.6951

# %%
Genderwise_Avg_Age = data.groupby(['Sex'])['Age'].mean()
Genderwise_Avg_Age
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
data.groupby(['Embarked'])['Age'].mean()
# Out:
# Embarked
# C    30.814769
# Q    28.089286
# S    29.445397
# Name: Age, dtype: float64

# %%
data.groupby(['Sex'])['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
Sex_Survived_Sum = data.groupby(['Sex'])['Survived'].sum().reset_index()

# %%
Sex_Survived_Sum
# Out:
#       Sex  Survived
# 0  female       233
# 1    male       109

# %%
Sex_Survived_Average = data.groupby(['Sex'])['Survived'].mean()*100

# %%
Sex_Survived_Average
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
data.groupby(['Embarked'])['Survived'].sum().reset_index()
# Out:
#   Embarked  Survived
# 0        C        93
# 1        Q        30
# 2        S       217

# %%
data.groupby(['Embarked'])['Fare'].sum().reset_index()
# Out:
#   Embarked        Fare
# 0        C  10072.2962
# 1        Q   1022.2543
# 2        S  17439.3988

# %%
data.groupby(['Pclass'])['Fare'].sum().reset_index()
# Out:
#    Pclass        Fare
# 0       1  18177.4125
# 1       2   3801.8417
# 2       3   6714.6951

# %%
data.groupby(['Pclass', 'Embarked'])['Fare'].sum().reset_index()
# Out:
#    Pclass Embarked       Fare
# 0       1        C  8901.0750
# 1       1        Q   180.0000
# 2       1        S  8936.3375
# 3       2        C   431.0917
# 4       2        Q    37.0500
# 5       2        S  3333.7000
# 6       3        C   740.1295
# 7       3        Q   805.2043
# 8       3        S  5169.3613

# %%
data.groupby(['Embarked', 'Pclass'])['Fare'].sum().reset_index()
# Out:
#   Embarked  Pclass       Fare
# 0        C       1  8901.0750
# 1        C       2   431.0917
# 2        C       3   740.1295
# 3        Q       1   180.0000
# 4        Q       2    37.0500
# 5        Q       3   805.2043
# 6        S       1  8936.3375
# 7        S       2  3333.7000
# 8        S       3  5169.3613

# %% [markdown]
# #### Querying the data

# %%
data[data['Sex'] == 'male']
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
data.query("Sex == 'male'")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
data.query("Sex == 'female'")
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 880         1       2  female  25.0      0      1  26.0000        S
# 882         0       3  female  22.0      0      0  10.5167        S
# 885         0       3  female  39.0      0      5  29.1250        Q
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
#
# [314 rows x 8 columns]

# %%
data.query("Survived == 1")
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 875         1       3  female  15.0      0      0   7.2250        C
# 879         1       1  female  56.0      0      1  83.1583        C
# 880         1       2  female  25.0      0      1  26.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
#
# [342 rows x 8 columns]

# %%
data.query("Embarked == 'Q'")
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 5           0       3    male   NaN      0      0   8.4583        Q
# 16          0       3    male   2.0      4      1  29.1250        Q
# 22          1       3  female  15.0      0      0   8.0292        Q
# 28          1       3  female   NaN      0      0   7.8792        Q
# 32          1       3  female   NaN      0      0   7.7500        Q
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 790         0       3    male   NaN      0      0   7.7500        Q
# 825         0       3    male   NaN      0      0   6.9500        Q
# 828         1       3    male   NaN      0      0   7.7500        Q
# 885         0       3  female  39.0      0      5  29.1250        Q
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [77 rows x 8 columns]

# %%
data.query("Sex == 'male' & Embarked == 'S'")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# 12          0       3  male  20.0      0      0   8.0500        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 878         0       3  male   NaN      0      0   7.8958        S
# 881         0       3  male  33.0      0      0   7.8958        S
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
#
# [441 rows x 8 columns]

# %%
data.query("Survived == 1 & Sex == 'female'")
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 874         1       2  female  28.0      1      0  24.0000        C
# 875         1       3  female  15.0      0      0   7.2250        C
# 879         1       1  female  56.0      0      1  83.1583        C
# 880         1       2  female  25.0      0      1  26.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
#
# [233 rows x 8 columns]

# %%
data.query("Survived == 1 & Sex == 'female' & Embarked == 'C'")
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 1           1       1  female  38.0      1      0   71.2833        C
# 9           1       2  female  14.0      1      0   30.0708        C
# 19          1       3  female   NaN      0      0    7.2250        C
# 31          1       1  female   NaN      1      0  146.5208        C
# 39          1       3  female  14.0      1      0   11.2417        C
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 858         1       3  female  24.0      0      3   19.2583        C
# 866         1       2  female  27.0      1      0   13.8583        C
# 874         1       2  female  28.0      1      0   24.0000        C
# 875         1       3  female  15.0      0      0    7.2250        C
# 879         1       1  female  56.0      0      1   83.1583        C
#
# [64 rows x 8 columns]

# %%
data.query("Sex == 'male' & Embarked == 'S' & Pclass == 3")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 7           0       3  male   2.0      3      1  21.0750        S
# 12          0       3  male  20.0      0      0   8.0500        S
# 13          0       3  male  39.0      1      5  31.2750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 876         0       3  male  20.0      0      0   9.8458        S
# 877         0       3  male  19.0      0      0   7.8958        S
# 878         0       3  male   NaN      0      0   7.8958        S
# 881         0       3  male  33.0      0      0   7.8958        S
# 884         0       3  male  25.0      0      0   7.0500        S
#
# [265 rows x 8 columns]

# %%
Sex_male_01 = data.query("Sex == 'male'")
Sex_male_01
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
Sex_Female = data.query("Sex != 'male'")
Sex_Female
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 880         1       2  female  25.0      0      1  26.0000        S
# 882         0       3  female  22.0      0      0  10.5167        S
# 885         0       3  female  39.0      0      5  29.1250        Q
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
#
# [314 rows x 8 columns]

# %%
Fare_under10 = data.query("Fare < 10 & Age >= 10")
Fare_under10
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Fare Embarked
# 0           0       3    male  22.0      1      0  7.2500        S
# 2           1       3  female  26.0      0      0  7.9250        S
# 4           0       3    male  35.0      0      0  8.0500        S
# 12          0       3    male  20.0      0      0  8.0500        S
# 14          0       3  female  14.0      0      0  7.8542        S
# ..        ...     ...     ...   ...    ...    ...     ...      ...
# 876         0       3    male  20.0      0      0  9.8458        S
# 877         0       3    male  19.0      0      0  7.8958        S
# 881         0       3    male  33.0      0      0  7.8958        S
# 884         0       3    male  25.0      0      0  7.0500        S
# 890         0       3    male  32.0      0      0  7.7500        Q
#
# [235 rows x 8 columns]

# %%
Sex_Age_20 = data.query("Sex == 'male' & Age == 22.0")

# %%
Sex_Age_20
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3  male  22.0      1      0    7.2500        S
# 60          0       3  male  22.0      0      0    7.2292        C
# 80          0       3  male  22.0      0      0    9.0000        S
# 112         0       3  male  22.0      0      0    8.0500        S
# 212         0       3  male  22.0      0      0    7.2500        S
# 225         0       3  male  22.0      0      0    9.3500        S
# 243         0       3  male  22.0      0      0    7.1250        S
# 287         0       3  male  22.0      0      0    7.8958        S
# 320         0       3  male  22.0      0      0    7.2500        S
# 373         0       1  male  22.0      0      0  135.6333        C
# 395         0       3  male  22.0      0      0    7.7958        S
# 478         0       3  male  22.0      0      0    7.5208        S
# 521         0       3  male  22.0      0      0    7.8958        S
# ...

# %%
data.query("Sex == 'male' & Age == 90")
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %% [markdown]
# ### Pivot()

# %%
data.pivot_table(values= 'Fare', index= 'Sex', columns= 'Pclass', aggfunc= 'sum')
# Out:
# Pclass          1          2          3
# Sex
# female  9975.8250  1669.7292  2321.1086
# male    8201.5875  2132.1125  4393.5865

# %%
data.pivot_table(values= 'Fare', index= 'Pclass', columns= 'Sex', aggfunc= 'mean')
# Out:
# Sex         female       male
# Pclass
# 1       106.125798  67.226127
# 2        21.970121  19.741782
# 3        16.118810  12.661633

# %%
data.pivot_table(values= 'Fare', index= 'Pclass', columns= 'Sex', aggfunc= 'mean', margins= True)
# Out:
# Sex         female       male        All
# Pclass
# 1       106.125798  67.226127  84.154687
# 2        21.970121  19.741782  20.662183
# 3        16.118810  12.661633  13.675550
# All      44.479818  25.523893  32.204208

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.pivot_table(values= 'Age', index= 'Embarked', columns= 'Sex', aggfunc= 'mean')
# Out:
# Sex          female       male
# Embarked
# C         28.344262  32.998841
# Q         24.291667  30.937500
# S         27.771505  30.291440

# %%
pivot_02 = data.pivot_table(values='Fare', index='Embarked', columns='Pclass', aggfunc='sum')

# %%
pivot_02

# %%
pivot_03 = data.pivot_table(values='Fare', index='Embarked', columns='Pclass', aggfunc='mean')

# %%
pivot_03

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
data.select_dtypes(int)
# Out:
#      Survived  Pclass  SibSp  Parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
data.select_dtypes(float)
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.select_dtypes('int64')

# %%
data.select_dtypes(int)

# %%
data.select_dtypes(float)

# %%
data.select_dtypes(object)
# Out:
#         Sex Embarked
# 0      male        S
# 1    female        C
# 2    female        S
# 3    female        S
# 4      male        S
# ..      ...      ...
# 886    male        S
# 887  female        S
# 888  female        S
# 889    male        C
# 890    male        Q
#
# [891 rows x 2 columns]

# %% [markdown]
# ### cumsum()

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
data[['Embarked', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Survived']]
# Out:
#     Embarked  Pclass     Sex   Age  SibSp  Parch  Survived
# 0          S       3    male  22.0      1      0         0
# 1          C       1  female  38.0      1      0         1
# 2          S       3  female  26.0      0      0         1
# 3          S       1  female  35.0      1      0         1
# 4          S       3    male  35.0      0      0         0
# ..       ...     ...     ...   ...    ...    ...       ...
# 886        S       2    male  27.0      0      0         0
# 887        S       1  female  19.0      0      0         1
# 888        S       3  female   NaN      1      2         0
# 889        C       1    male  26.0      0      0         1
# 890        Q       3    male  32.0      0      0         0
#
# [891 rows x 7 columns]

# %%
data[['Fare', 'Age']]
# Out:
#         Fare   Age
# 0     7.2500  22.0
# 1    71.2833  38.0
# 2     7.9250  26.0
# 3    53.1000  35.0
# 4     8.0500  35.0
# ..       ...   ...
# 886  13.0000  27.0
# 887  30.0000  19.0
# 888  23.4500   NaN
# 889  30.0000  26.0
# 890   7.7500  32.0
#
# [891 rows x 2 columns]

# %%
data[['Fare', 'Age']].cumsum()
# Out:
#            Fare       Age
# 0        7.2500     22.00
# 1       78.5333     60.00
# 2       86.4583     86.00
# 3      139.5583    121.00
# 4      147.6083    156.00
# ..          ...       ...
# 886  28602.7493  21128.17
# 887  28632.7493  21147.17
# 888  28656.1993       NaN
# 889  28686.1993  21173.17
# 890  28693.9493  21205.17
#
# [891 rows x 2 columns]

# %% [markdown]
# ### replace

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Sex.replace({'male':0, 'female':1}, inplace=True)

# %%
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.0      1      0   7.2500        S
# 1           1       1    1  38.0      1      0  71.2833        C
# 2           1       3    1  26.0      0      0   7.9250        S
# 3           1       1    1  35.0      1      0  53.1000        S
# 4           0       3    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    0  27.0      0      0  13.0000        S
# 887         1       1    1  19.0      0      0  30.0000        S
# 888         0       3    1   NaN      1      2  23.4500        S
# 889         1       1    0  26.0      0      0  30.0000        C
# 890         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Sex.replace({0:'male', 1:'female'}, inplace=True)
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Pclass.replace({3:'Third', 2:'Second', 1:'First'}, inplace=True)
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0   Third    male  22.0      1      0   7.2500        S
# 1           1   First  female  38.0      1      0  71.2833        C
# 2           1   Third  female  26.0      0      0   7.9250        S
# 3           1   First  female  35.0      1      0  53.1000        S
# 4           0   Third    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0  Second    male  27.0      0      0  13.0000        S
# 887         1   First  female  19.0      0      0  30.0000        S
# 888         0   Third  female   NaN      1      2  23.4500        S
# 889         1   First    male  26.0      0      0  30.0000        C
# 890         0   Third    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Survived.replace({0:'Dead', 1:'Survived'}, inplace=True)
data.head(10)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0      Dead   Third    male  22.0      1      0   7.2500        S
# 1  Survived   First  female  38.0      1      0  71.2833        C
# 2  Survived   Third  female  26.0      0      0   7.9250        S
# 3  Survived   First  female  35.0      1      0  53.1000        S
# 4      Dead   Third    male  35.0      0      0   8.0500        S
# 5      Dead   Third    male   NaN      0      0   8.4583        Q
# 6      Dead   First    male  54.0      0      0  51.8625        S
# 7      Dead   Third    male   2.0      3      1  21.0750        S
# 8  Survived   Third  female  27.0      0      2  11.1333        S
# 9  Survived  Second  female  14.0      1      0  30.0708        C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 55.8+ KB

# %% [markdown]
# ### rename

# %%
data.rename(columns={'Sex':'SEX', 'SibSp':'SP'}, inplace=True)

# %%
data
# Out:
#      Survived  Pclass     SEX   Age  SP  Parch     Fare Embarked
# 0        Dead   Third    male  22.0   1      0   7.2500        S
# 1    Survived   First  female  38.0   1      0  71.2833        C
# 2    Survived   Third  female  26.0   0      0   7.9250        S
# 3    Survived   First  female  35.0   1      0  53.1000        S
# 4        Dead   Third    male  35.0   0      0   8.0500        S
# ..        ...     ...     ...   ...  ..    ...      ...      ...
# 886      Dead  Second    male  27.0   0      0  13.0000        S
# 887  Survived   First  female  19.0   0      0  30.0000        S
# 888      Dead   Third  female   NaN   1      2  23.4500        S
# 889  Survived   First    male  26.0   0      0  30.0000        C
# 890      Dead   Third    male  32.0   0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.rename(columns={'Fare':'Charge'}, inplace=True)
data.head(10)
# Out:
#    Survived  Pclass     SEX   Age  SP  Parch   Charge Embarked
# 0      Dead   Third    male  22.0   1      0   7.2500        S
# 1  Survived   First  female  38.0   1      0  71.2833        C
# 2  Survived   Third  female  26.0   0      0   7.9250        S
# 3  Survived   First  female  35.0   1      0  53.1000        S
# 4      Dead   Third    male  35.0   0      0   8.0500        S
# 5      Dead   Third    male   NaN   0      0   8.4583        Q
# 6      Dead   First    male  54.0   0      0  51.8625        S
# 7      Dead   Third    male   2.0   3      1  21.0750        S
# 8  Survived   Third  female  27.0   0      2  11.1333        S
# 9  Survived  Second  female  14.0   1      0  30.0708        C

# %% [markdown]
# ### fillna

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# SEX           0
# Age         177
# SP            0
# Parch         0
# Charge        0
# Embarked      2
# dtype: int64

# %%
data.Age.mean()
# Out:
# 29.69911764705882

# %%
data.Age.fillna(30, inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# SEX         0
# Age         0
# SP          0
# Parch       0
# Charge      0
# Embarked    2
# dtype: int64

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data.Embarked.fillna('S', inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# SEX         0
# Age         0
# SP          0
# Parch       0
# Charge      0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### pct_change

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.Fare.pct_change()

# %% [markdown]
# ### pd.cut

# %%
data

# %%
cutoff = [0, 18, 50, 85]
labels = ['Child', 'Adult', 'Old']
data['AGE_TYPE'] = pd.cut(data.Age, bins=cutoff, labels=labels)

# %%
data.sample(20)
# Out:
#      Survived  Pclass     SEX   Age  SP  Parch    Charge Embarked AGE_TYPE
# 160      Dead   Third    male  44.0   0      1   16.1000        S    Adult
# 874  Survived  Second  female  28.0   1      0   24.0000        C    Adult
# 574      Dead   Third    male  16.0   0      0    8.0500        S    Child
# 446  Survived  Second  female  13.0   0      1   19.5000        S    Child
# 530  Survived  Second  female   2.0   1      1   26.0000        S    Child
# 315  Survived   Third  female  26.0   0      0    7.8542        S    Adult
# 400  Survived   Third    male  39.0   0      0    7.9250        S    Adult
# 630  Survived   First    male  80.0   0      0   30.0000        S      Old
# 553  Survived   Third    male  22.0   0      0    7.2250        C    Adult
# 311  Survived   First  female  18.0   2      2  262.3750        C    Child
# 663      Dead   Third    male  36.0   0      0    7.4958        S    Adult
# ...

# %%
data.groupby(['AGE_TYPE'])['Survived'].sum().reset_index()

# %% [markdown]
# ### n_largets and n-smallest

# %%
data.nlargest(5, 'Age')
# Out:
#      Survived Pclass   SEX   Age  SP  Parch   Charge Embarked AGE_TYPE
# 630  Survived  First  male  80.0   0      0  30.0000        S      Old
# 851      Dead  Third  male  74.0   0      0   7.7750        S      Old
# 96       Dead  First  male  71.0   0      0  34.6542        C      Old
# 493      Dead  First  male  71.0   0      0  49.5042        C      Old
# 116      Dead  Third  male  70.5   0      0   7.7500        Q      Old

# %%
data.nsmallest(3, 'Age')
# Out:
#      Survived  Pclass     SEX   Age  SP  Parch   Charge Embarked AGE_TYPE
# 803  Survived   Third    male  0.42   0      1   8.5167        C    Child
# 755  Survived  Second    male  0.67   1      1  14.5000        S    Child
# 469  Survived   Third  female  0.75   2      1  19.2583        C    Child

# %% [markdown]
# ### CROSS TABULATION
# * In statistics, a contingency table (also known as a cross tabulation or crosstab) is a type of table in a matrix format that displays the (multivariate) frequency distribution of the variables. They are heavily used in survey research, business intelligence, engineering, and scientific research. They provide a basic picture of the interrelation between two variables and can help find interactions between them. The term contingency table was first used by Karl Pearson in "On the Theory of Contingency and Its Relation to Association and Normal Correlation",[1] part of the Drapers' Company Research Memoirs Biometric Series I published in 1904.

# %%
pd.crosstab(data.Pclass, data.Embarked)
# Out:
# Embarked   C   Q    S
# Pclass
# First     85   2  129
# Second    17   3  164
# Third     66  72  353

# %%
pd.crosstab(data.SEX, data.Embarked)
# Out:
# Embarked   C   Q    S
# SEX
# female    73  36  205
# male      95  41  441

# %%
pd.crosstab(data.Pclass, data.Embarked, margins=True)
# Out:
# Embarked    C   Q    S  All
# Pclass
# First      85   2  129  216
# Second     17   3  164  184
# Third      66  72  353  491
# All       168  77  646  891

# %%
data_cars = pd.read_csv('./Car_sales.csv')
data_cars
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...
