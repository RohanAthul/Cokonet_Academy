# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6

# %% [markdown]
# ## Cokonet

# %%
# Comment

# %% [markdown]
# ## <center> Heading

# %% [markdown]
# - One
# - Two
# - Three

# %% [markdown]
# ## Image
# ![image_3626089.png](attachment:e31cd150-c1fa-4dd5-858b-b27f607d5209.png)

# %%
# Multiplication
7 * 8
# Out:
# 56
